# %% [markdown]
# #1.Bank Account Manager

# %%
# deposit function
def deposit(balance):
    amount = int(input("Enter amount to deposit: "))
    balance = balance + amount
    print("Amount deposited")
    return balance


# withdraw function
def withdraw(balance):
    amount = int(input("Enter amount to withdraw: "))

    if amount <= balance:
        balance = balance - amount
        print("Amount withdrawn")
    else:
        print("Insufficient balance")

    return balance


# balance enquiry function
def check_balance(balance):
    print("Current balance is:", balance)


balance = 0

while True:
    print("\nBank Menu")
    print("1. Deposit")
    print("2. Withdraw")
    print("3. Balance Enquiry")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        balance = deposit(balance)

    elif choice == 2:
        balance = withdraw(balance)

    elif choice == 3:
        check_balance(balance)

    elif choice == 4:
        print("Thank you")
        break

    else:
        print("Invalid choice")
# Out:
# Bank Menu
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 4. Exit
# Enter your choice: 1
# Enter amount to deposit: 10000
# Amount deposited
#
# Bank Menu
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 4. Exit
# Enter your choice: 2
# Enter amount to withdraw: 200
# Amount withdrawn
#
# Bank Menu
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 4. Exit
# Enter your choice: 3
# Current balance is: 9800
#
# Bank Menu
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 4. Exit
# Enter your choice: 4
# Thank you

# %% [markdown]
# #2.Weather Data Analyzer

# %%
# storing temperature and humidity values
temperature1 = 30
temperature2 = 32
temperature3 = 28

humidity1 = 60
humidity2 = 65
humidity3 = 70

# function to find average temperature
def avg_temperature():
    avg_temp = (temperature1 + temperature2 + temperature3) / 3
    return avg_temp

# function to find average humidity
def avg_humidity():
    avg_hum = (humidity1 + humidity2 + humidity3) / 3
    return avg_hum

# calling the functions
average_temp = avg_temperature()
average_hum = avg_humidity()

# checking weather condition
if average_temp > 30:
    print("Weather Condition: Sunny")
elif average_hum > 65:
    print("Weather Condition: Rainy")
else:
    print("Weather Condition: Cloudy")

# printing average values
print("Average Temperature:", average_temp)
print("Average Humidity:", average_hum)
# Out:
# Weather Condition: Cloudy
# Average Temperature: 30.0
# Average Humidity: 65.0
